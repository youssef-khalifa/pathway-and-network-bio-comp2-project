# %%
import cobra

# %%
from cobra import *

# %%
from escher import Builder

# %%
model = Model('PATH')

# %%
###### Glycolysis Pathway start #######

###### =====>GLU
GLUin = Reaction('GLUin')
GLUin.name='Glucose import'
GLUin.lower_bound=1
GLUin.upper_bound=1

##### Gluc+ATP =========> G6P+ADP+H
HK=Reaction('HK')
HK.name='Hixokinasis'
HK.lower_bound=0
HK.upper_bound=1000

##### G6P <=========> F6P
PGI=Reaction('PGI')
PGI.name='Glucose 6-phosphate isomerase'
PGI.lower_bound=-1000
PGI.upper_bound=1000

#####F6P+ATP=======>FDP+ADP+H
PFK=Reaction('PFK')
PFK.name='Phosphofructokinase'
PFK.lower_bound=0
PFK.upper_bound=1000

#####DHAP<===========>G3P
TPI=Reaction('TPI')
TPI.name='Triose-phosphate isomerase'
TPI.lower_bound=-1000
TPI.upper_bound=1000

#####FDP<===========>DHAP+G3P
ALD=Reaction('ALD')
ALD.name='Fructose 1,6-diphosphate aldolase'
ALD.lower_bound=-1000
ALD.upper_bound=1000

#####G3P+NAD+Pi<===========>DPG13+NADH+H
GAPDH=Reaction('GAPDH')
GAPDH.name='Glyceraldehyde 3-phosphate dehydrogenase'
GAPDH.lower_bound=-1000
GAPDH.upper_bound=1000

#####DPG13 + ADP<===========>PG3 + ATP
PGK=Reaction('PGK')
PGK.name='Phosphoglycerate kinase'
PGK.lower_bound=-1000
PGK.upper_bound=1000

#####PG3<===========>PG2
PGLM=Reaction('PGLM')
PGLM.name='Phosphoglycerate mutase'
PGLM.lower_bound=-1000
PGLM.upper_bound=1000

#####PG2<===========>PEP + H2O
ENO=Reaction('ENO')
ENO.name='Enolase'
ENO.lower_bound=-1000
ENO.upper_bound=1000

#####PEP + ADP + H ===========>PYR + ATP
PK=Reaction('PK')
PK.name='Pyruvate kinase'
PK.lower_bound=0
PK.upper_bound=1000

#####PYR + H ===========> Acetaldehyde + CO2
PKF=Reaction('PKF')
PKF.name='Pyruvate Fermentation'
PKF.lower_bound=0
PKF.upper_bound=1000

#####Acetaldehyde + NADH + H → Ethanol + NAD+
ETH=Reaction('ETH')
ETH.name=''
ETH.lower_bound=-1000
ETH.upper_bound=1000

####Ethanol <========> 
ETHe=Reaction('ETHe')
ETHe.name='Ethanol exchange'
ETHe.lower_bound=-1000
ETHe.upper_bound=1000

# ####PYR + NADH + H ===========>LAC + NAD
LDH=Reaction('LDH')
LDH.name='Lactate dehydrogenase'
LDH.lower_bound=-1000
LDH.upper_bound=1000

#####AMP ========>
AMPe=Reaction('AMPe')
AMPe.name='AMP export'
AMPe.lower_bound=0
AMPe.upper_bound=1000
              
#####2ADP <========> AMP + ATP
APK=Reaction('APK')
APK.name='Adenylate kinase'
APK.lower_bound=-1000
APK.upper_bound=1000

#####PYR <========> 
PYRe=Reaction('PYRe')
PYRe.name='Pyruvate exchange'
PYRe.lower_bound=-1000
PYRe.upper_bound=1000

# ####LAC <========> 
LACe=Reaction('LACe')
LACe.name='Lactate exchange'
LACe.lower_bound=-1000
LACe.upper_bound=1000

#####ATP + H2O ========> ADP + Pi + H
ATPh=Reaction('ATPh')
ATPh.name='ATP hydrolysis'
ATPh.lower_bound=0
ATPh.upper_bound=1000

#####NADH ========> NAD + H
NADHo=Reaction('NADHo')
NADHo.name='NADH oxidation'
NADHo.lower_bound=0
NADHo.upper_bound=1000

##### ========> AMP
AMPin=Reaction('AMPin')
AMPin.name='AMP import'
AMPin.lower_bound=1
AMPin.upper_bound=1

##### H <========> 
He=Reaction('He')
He.name='Proton exchange'
He.lower_bound=-1000
He.upper_bound=1000

##### H2O <========> 
H2Oe=Reaction('H2Oe')
H2Oe.name='Water exchange'
H2Oe.lower_bound=-1000
H2Oe.upper_bound=1000

##### Glycolysis Pathway end #######
###########################################################################
##### TCA Cycle start ######

##### PYR + NAD + CoA ========> Acetyl-CoA + NADH + CO2
ACTL=Reaction('ACTL')
ACTL.name='Pyruvate dehydrogenase complex'
ACTL.lower_bound=0
ACTL.upper_bound=1000

##### Acetyl-CoA + oxaloacetate + H2O <========> citrate + CoA
CIT=Reaction('CIT')
CIT.name='Citrate synthase'
CIT.lower_bound=-1000
CIT.upper_bound=1000

##### citrate <=====> cis-aconitate + H2O
Aco1=Reaction('Aco1')
Aco1.name='Aconitase'
Aco1.lower_bound=-1000
Aco1.upper_bound=1000

##### cis-aconitate + H2O <=====> isocitrate
Aco2=Reaction('Aco2')
Aco2.name='Aconitase'
Aco2.lower_bound=-1000
Aco2.upper_bound=1000

##### isocitrate + NAD <=====> aketo + CO2 + NADH + H
iso=Reaction('iso')
iso.name='Isocitrate dehydrogenase'
iso.lower_bound=-1000
iso.upper_bound=1000

##### aketo + NAD + CoA <=====> sussinyl-CoA + CO2 + NADH + H
ketod=Reaction('ketod')
ketod.name='a-ketoglutarate dehydrogenase complex'
ketod.lower_bound=-1000
ketod.upper_bound=1000

##### sussinyl-CoA + Pi + ADP <=====> succinate + ATP + CoA
Succsyn=Reaction('Succsyn')
Succsyn.name='Succinyl-CoA synthetase'
Succsyn.lower_bound=-1000
Succsyn.upper_bound=1000

##### sussinate + FAD <=====> fumarate + FADH2
Succd=Reaction('Succd')
Succd.name='Succinate dehydrogenase'
Succd.lower_bound=-1000
Succd.upper_bound=1000

##### fumarate + H2O <=====> L-Malate
Fum=Reaction('Fum')
Fum.name='Fumarase'
Fum.lower_bound=-1000
Fum.upper_bound=1000

##### L-Malate + NAD <=====> oxaloacetate + NADH + H
Mald=Reaction('Mald')
Mald.name='Malate dehydrogenase'
Mald.lower_bound=-1000
Mald.upper_bound=1000

##### TCA Cycle end ######

##### PPP start ######

##### G6P + NADP =====> GL6P + NADPH + H
G6PDH=Reaction('G6PDH')
G6PDH.name='glucose 6-phosphate dehydrogenase'
G6PDH.lower_bound=0
G6PDH.upper_bound=1000

##### GL6P + H2O =====> GO6P + H
PGLase=Reaction('PGLase')
PGLase.name='6-phosphogluconolactonase'
PGLase.lower_bound=0
PGLase.upper_bound=1000

##### GO6P + NADP =====> RU5P + NADPH + CO2
GL6PDH=Reaction('GL6PDH')
GL6PDH.name='GO6P dehydrogenase'
GL6PDH.lower_bound=0
GL6PDH.upper_bound=1000

##### CO2 =====> CO2
CO2e=Reaction('CO2e')
CO2e.name='CO2 exit'
CO2e.lower_bound=0
CO2e.upper_bound=1000

##### RU5P <=====> X5P
R5PE=Reaction('R5PE')
R5PE.name='X5P epimerase'
R5PE.lower_bound=-1000
R5PE.upper_bound=1000

##### RU5P <=====> R5P
R5PI=Reaction('R5PI')
R5PI.name='R5P isomerase'
R5PI.lower_bound=-1000
R5PI.upper_bound=1000

##### X5P + R5P <=====> S7P + GAP
TKI=Reaction('TKI')
TKI.name='Transketolase I'
TKI.lower_bound=-1000
TKI.upper_bound=1000

##### X5P + E4P <=====> F6P + GAP
TKII=Reaction('TKII')
TKII.name='Transketolase II'
TKII.lower_bound=-1000
TKII.upper_bound=1000

##### S7P + GAP <=====> E4P + F6P
TALA=Reaction('TALA')
TALA.name='Transaldolase'
TALA.lower_bound=-1000
TALA.upper_bound=1000

##### GSSG + NADPH + H <=====> 2GSH + NADP
GSSGR=Reaction('GSSGR')
GSSGR.name='Glutathione reductase'
GSSGR.lower_bound=-1000
GSSGR.upper_bound=1000

##### 2GSH <=====> GSSG + 2H
GSHR=Reaction('GSHR')
GSHR.name='Glutathione oxidase'
GSHR.lower_bound=-1000
GSHR.upper_bound=1000

##### PPP end ######

##### Oxidative Phoso Start ######

##### NADH + Q + 5H =====> NAD + QH2 + 4H
NADHQ=Reaction('NADHQ')
NADHQ.name='NADH-coenzyme Q oxidoreductase (complex I)'
NADHQ.lower_bound=0
NADHQ.upper_bound=1000

##### Succinate + Q =====> QH2 + Fumarate
SUCCQ=Reaction('SUCCQ')
SUCCQ.name='Succinate-Q oxidoreductase (complex II)'
SUCCQ.lower_bound=0
SUCCQ.upper_bound=1000

##### QH2 + 2Fe3+ =====> Q + 2Fe2+ + 2H
QUIN=Reaction('QUIN')
QUIN.name='Quinol--cytochrome-c reductase (complex III)'
QUIN.lower_bound=0
QUIN.upper_bound=1000

##### 8H + 4Fe2+ + O2 =====> 2H2O + 4Fe3+ + 4H
CYTO=Reaction('CYTO')
CYTO.name='Cytochrome-c oxidase (complex IV)'
CYTO.lower_bound=0
CYTO.upper_bound=1000

##### ATP + 4H + H2O <=====> ADP + 5H + P
ATPase=Reaction('ATPase')
ATPase.name='H(+)-transporting two-sector ATPase'
ATPase.lower_bound=-1000
ATPase.upper_bound=1000

##### Pi + H2O <=====> H + 2P
Phos=Reaction('Phos')
Phos.name='Inorganic diphosphatase'
Phos.lower_bound=-1000
Phos.upper_bound=1000

##### PPi + ATP <=====> ADP + PPPi
ATPPoly=Reaction('ATPPoly')
ATPPoly.name='ATP-polyphosphate phosphotransferase'
ATPPoly.lower_bound=-1000
ATPPoly.upper_bound=1000

##### 1/2 O2 + NADH + H =====> H2O + NAD
energ=Reaction('energ')
energ.name='energitics'
energ.lower_bound=0
energ.upper_bound=1000

##### Oxidative Phoso end ######

##### Biomass
MASS=Reaction('MASS')
MASS.name='Biomass Objective Function with GAM'
MASS.lower_bound=0
MASS.upper_bound=1000

Pie=Reaction('Pie')
Pie.name='Biomass Objective Function with GAM'
Pie.lower_bound=-1000
Pie.upper_bound=1000

# "adp_c":1.0,"atp_c":-1.0,"gln__L_c":1.0,"glu__L_c":-1.0,"h_c":1.0,"nh4_c":-1.0,"pi_c":1.0
GLNS=Reaction('GLNS')
GLNS.name='Glutamine synthetase'
GLNS.lower_bound=0
GLNS.upper_bound=1000

GLUDy=Reaction('GLUDy')
GLUDy.name='Glutamate dehydrogenase (NADP)'
GLUDy.lower_bound=-1000
GLUDy.upper_bound=1000

GLUN=Reaction('GLUN')
GLUN.name='Glutaminase'
GLUN.lower_bound=0
GLUN.upper_bound=1000

GLUSy=Reaction('GLUSy')
GLUSy.name='Glutamate synthase (NADPH)'
GLUSy.lower_bound=0
GLUSy.upper_bound=1000

GLUt2r=Reaction('GLUt2r')
GLUt2r.name='L glutamate transport via proton symport  reversible'
GLUt2r.lower_bound=-1000
GLUt2r.upper_bound=1000

GLNabc=Reaction('GLNabc')
GLNabc.name='L-glutamine transport via ABC system'
GLNabc.lower_bound=0
GLNabc.upper_bound=1000

Acetale=Reaction('Acetale')
Acetale.name=''
Acetale.lower_bound=-1000
Acetale.upper_bound=1000

nh4e=Reaction('nh4e')
nh4e.name='Amonia Exchange'
nh4e.lower_bound=-1000
nh4e.upper_bound=1000

Oxae=Reaction('Oxae')
Oxae.name='oxaloacetate exchange'
Oxae.lower_bound=-1000
Oxae.upper_bound=1000

aketoe=Reaction('aketoe')
aketoe.name='a-ketogularate exchange'
aketoe.lower_bound=-1000
aketoe.upper_bound=1000

Lmalate_e=Reaction('Lmalate_e')
Lmalate_e.name='Lmalate exchange'
Lmalate_e.lower_bound=-1000
Lmalate_e.upper_bound=1000

succinate_e=Reaction('succinate_e')
succinate_e.name='succinate exchange'
succinate_e.lower_bound=-1000
succinate_e.upper_bound=1000

glue=Reaction('glue')
glue.name='succinate_e exchange'
glue.lower_bound=-1000
glue.upper_bound=1000

glne=Reaction('glne')
glne.name='succinate_e exchange'
glne.lower_bound=-1000
glne.upper_bound=1000

fumurate_e=Reaction('fumurate_e')
fumurate_e.name='fumurate_e exchange'
fumurate_e.lower_bound=0
fumurate_e.upper_bound=1000

FDPe=Reaction('FDPe')
FDPe.name='FDPe exchange'
FDPe.lower_bound=0
FDPe.upper_bound=1000

#Acetylcoa + P <===> Acetyl-Phosphate +CoA
PTAr=Reaction("PTAr")
PTAr.name='Phosphotransacetylase'
PTAr.lower_bound=-1000
PTAr.upper_bound=1000

#Acetyl-Phosphate + ADP ===> Acetate + ATP
ACK=Reaction("ACK")
ACK.name='Acetate kinase'
ACK.lower_bound=-1000
ACK.upper_bound=1000

ACTe=Reaction("ACTe")
ACTe.name='Acetate Exchange'
ACTe.lower_bound=0
ACTe.upper_bound=1000

# %%
Gluc=Metabolite(
    'Gluc',
    formula='C6H12O6',
    name='Glucose',
    compartment='c')
ATP=Metabolite(
    'ATP',
    formula='C10H12N5O13P3',
    name='Adenosise tri-phosphate',
    compartment='c')
ADP=Metabolite(
    'ADP',
    formula='C10H15N5O10P2',
    name='Adenosise di-phosphate',
    compartment='c')
G6P=Metabolite(
    'G6P',
    formula='C6H13O9P',
    name='Glucose 6-phosphate',
    compartment='c')
H=Metabolite(
    'H',
    formula='H',
    name='Proton',
    compartment='c')
FDP=Metabolite(
    'FDP',
    formula='',
    name='Fructose 1,6-diphosphate',
    compartment='c')
F6P=Metabolite(
    'F6P',
    formula='',
    name='Fructose 6-phosphate',
    compartment='c')
DHAP=Metabolite(
    'DHAP',
    formula='',
    name='Dihydroxyacetone phosphate',
    compartment='c')
G3P=Metabolite(
    'G3P',
    formula='',
    name='Glyceraldehyde 3-phosphate',
    compartment='c')
NAD=Metabolite(
    'NAD',
    formula='C21H26N7O14P2',
    name='Nicotinamide adenine dinucleotide (oxidized)',
    compartment='c')
NADH=Metabolite(
    'NADH',
    formula='C21H27N7O14P2',
    name='Nicotinamide adenine dinucleotide (reduced)',
    compartment='c')
P=Metabolite(
    'P',
    formula='',
    name='Inorganic phosphate',
    compartment='c')
DPG13=Metabolite(
    'DPG13',
    formula='',
    name='1,3-Diphosphoglycerate',
    compartment='c')
PG3=Metabolite(
    'PG3',
    formula='',
    name='3-Phosphoglycerate',
    compartment='c')
PG2=Metabolite(
    'PG2',
    formula='',
    name='2-Phosphoglycerate',
    compartment='c')
PEP=Metabolite(
    'PEP',
    formula='',
    name='Phosphoenolpyruvate',
    compartment='c')
H2O=Metabolite(
    'H2O',
    formula='',
    name='Water',
    compartment='c')
PYR=Metabolite(
    'PYR',
    formula='',
    name='Pyruvate',
    compartment='c')
LAC=Metabolite(
    'LAC',
    formula='',
    name='Lactate',
    compartment='c')
AMP=Metabolite(
    'AMP',
    formula='',
    name='AMP',
    compartment='c')
CoA=Metabolite(
    'CoA',
    formula='',
    name='CoA',
    compartment='c')
AcetylCoA=Metabolite(
    'Acetyl-CoA',
    formula='',
    name='Acetyl-CoA',
    compartment='c')
CO2=Metabolite(
    'CO2',
    formula='',
    name='CO2',
    compartment='c')
oxaloacetate=Metabolite(
    'oxaloacetate',
    formula='',
    name='oxaloacetate',
    compartment='c')
citrate=Metabolite(
    'citrate',
    formula='',
    name='citrate',
    compartment='c')
cisaconitate=Metabolite(
    'cisaconitate',
    formula='',
    name='cis-aconitate',
    compartment='c')
isocitrate=Metabolite(
    'isocitrate',
    formula='',
    name='isocitrate',
    compartment='c')
aketo=Metabolite(
    'aketo',
    formula='',
    name='a-ketoglutarate',
    compartment='c')
sussinylCoA=Metabolite(
    'sussinylCoA',
    formula='',
    name='sussinyl-CoA',
    compartment='c')
Pi=Metabolite(
    'Pi',
    formula='',
    name='ortho phosphate',
    compartment='c')
succinate=Metabolite(
    'succinate',
    formula='',
    name='succinate',
    compartment='c')
FAD=Metabolite(
    'FAD',
    formula='',
    name='FAD',
    compartment='c')
FADH2=Metabolite(
    'FADH2',
    formula='',
    name='FADH2',
    compartment='c')
fumarate=Metabolite(
    'fumarate',
    formula='',
    name='fumarate',
    compartment='c')
Lmalate=Metabolite(
    'Lmalate',
    formula='',
    name='L-Malate',
    compartment='c')
NADP=Metabolite(
    'NADP',
    formula='',
    name='NADP',
    compartment='c')
NADPH=Metabolite(
    'NADPH',
    formula='',
    name='NADPH',
    compartment='c')
GL6P=Metabolite(
    'GL6P',
    formula='',
    name='6-phosphoglucono-δ-lactone',
    compartment='c')
GO6P=Metabolite(
    'GO6P',
    formula='',
    name='6-phosphogluconate',
    compartment='c')
RU5P=Metabolite(
    'RU5P',
    formula='',
    name='RU5P',
    compartment='c')
X5P=Metabolite(
    'X5P',
    formula='',
    name='X5P',
    compartment='c')
R5P=Metabolite(
    'R5P',
    formula='',
    name='R5P',
    compartment='c')
S7P=Metabolite(
    'S7P',
    formula='',
    name='S7P',
    compartment='c')
GAP=Metabolite(
    'GAP',
    formula='',
    name='GAP',
    compartment='c')
E4P=Metabolite(
    'E4P',
    formula='',
    name='E4P',
    compartment='c')
GSSG=Metabolite(
    'GSSG',
    formula='',
    name='GSSG',
    compartment='c')
GSH=Metabolite(
    'GSH',
    formula='',
    name='GSH',
    compartment='c')
#####################################
Q=Metabolite(
    'Q',
    formula='C9H10O4(C5H8)n',
    name='a ubiquinone',
    compartment='c')
QH2=Metabolite(
    'QH2',
    formula='C9H12O4(C5H8)n',
    name='a ubiquinol',
    compartment='c')
Fe3=Metabolite(
    'Fe3',
    formula='Fe',
    name='Fe(III)-[cytochrome c]',
    compartment='c')
Fe2=Metabolite(
    'Fe2',
    formula='Fe',
    name='Fe(II)-[cytochrome c]',
    compartment='c')
O2=Metabolite(
    'O2',
    formula='O2',
    name='O2',
    compartment='c')
PPi=Metabolite(
    'PPi',
    formula='',
    name='diphosphate',
    compartment='c')
PPPi=Metabolite(
    'PPPi',
    formula='',
    name='triphosphate',
    compartment='c')
Acetaldehyde=Metabolite(
    'Acetaldehyde',
    formula='CH3CHO',
    name='Acetaldehyde',
    compartment='c')
Ethanol=Metabolite(
    'Ethanol',
    formula='C2H5OH',
    name='Ethanol',
    compartment='c')
gln=Metabolite(
    'gln',
    formula='C5H10N2O3',
    name='L-Glutamine',
    compartment='c')
glu=Metabolite(
    'glu',
    formula='C5H8NO4',
    name='L-Glutamate',
    compartment='c')
nh4=Metabolite(
    'nh4',
    formula='H4N',
    name='Ammonium',
    compartment='c')
act=Metabolite(
    'Acetate',
    name= "Acetate",
    formula="C2H3O2",
    compartment='c')
actp=Metabolite(
    'Acetyl_phosphate',
    name= "Acetyl phosphate",
    formula="C2H3O5P",
    compartment='c')

# %%
GLUin.add_metabolites({Gluc:1})
HK.add_metabolites({Gluc:-1,ATP:-1,G6P:1,ADP:1,H:1})
PGI.add_metabolites({G6P:-1,F6P:1})
PFK.add_metabolites({F6P:-1,ATP:-1,FDP:1,ADP:1,H:1})
TPI.add_metabolites({DHAP:-1,G3P:1})
ALD.add_metabolites({FDP:-1,DHAP:1,G3P:1})
GAPDH.add_metabolites({G3P:-1,NAD:-1,Pi:-1,DPG13:1,NADH:1,H:1})
PGK.add_metabolites({DPG13:-1,ADP:-1,PG3:1,ATP:1})
PGLM.add_metabolites({PG3:-1,PG2:1})
ENO.add_metabolites({PG2:-1,PEP:1,H2O:1})
PK.add_metabolites({PEP:-1,ADP:-1,H:-1,PYR:2,ATP:1})
PKF.add_metabolites({PYR:-1,H:-1,Acetaldehyde:1,CO2:1})
# ETH.add_metabolites({Acetaldehyde:-1,NADH:-1,H:-1,Ethanol:1,NAD:1})
LDH.add_metabolites({PYR:-1,NADH:-1,H:-1,LAC:-1,NAD:-1})
# ETHe.add_metabolites({Ethanol:-1})
AMPe.add_metabolites({AMP:-1})
APK.add_metabolites({ADP:-2,AMP:1,ATP:1})
PYRe.add_metabolites({PYR:-1})
LACe.add_metabolites({LAC:-1})
ATPh.add_metabolites({ATP:-1,H2O:-1,ADP:1,Pi:1,H:1})
NADHo.add_metabolites({NADH:1,NAD:-1,H:1})
AMPin.add_metabolites({AMP:1})
He.add_metabolites({H:-1})
H2Oe.add_metabolites({H2O:-1})
Pie.add_metabolites({Pi:-1})
ACTL.add_metabolites({PYR:-1,NAD:-1,CoA:-1,AcetylCoA:1,NADH:1,CO2:1})
CIT.add_metabolites({AcetylCoA:-1,oxaloacetate:-1,H2O:-1,citrate:1,CoA:1})
Aco1.add_metabolites({citrate:-1,cisaconitate:1,H2O:1})
Aco2.add_metabolites({cisaconitate:-1,H2O:-1,isocitrate:1})
iso.add_metabolites({isocitrate:-1,NAD:-1,aketo:1,CO2:1,NADH:1,H:1})
ketod.add_metabolites({aketo:-1,NAD:-1,CoA:-1,sussinylCoA:1,CO2:1,NADH:1,H:1})
Succsyn.add_metabolites({sussinylCoA:-1,Pi:-1,ADP:-1,succinate:1,ATP:1,CoA:1})
Succd.add_metabolites({succinate:-1,FAD:-1,Pi:-1,fumarate:1,FADH2:1})
Fum.add_metabolites({fumarate:-1,H2O:-1,Lmalate:1})
Mald.add_metabolites({Lmalate:-1,NAD:-1,oxaloacetate:1,NADH:1,H:1})
G6PDH.add_metabolites({G6P:-1,NADP:-1,GL6P:1,NADPH:1,H:1})
PGLase.add_metabolites({GL6P:-1,H2O:-1,GO6P:1,H:1})
GL6PDH.add_metabolites({GO6P:-1,NADP:-1,RU5P:1,NADPH:1,CO2:1})
CO2e.add_metabolites({CO2:-1,CO2:1})
R5PE.add_metabolites({RU5P:-1,X5P:1})
R5PI.add_metabolites({RU5P:-1,R5P:1})
TKI.add_metabolites({X5P:-1,R5P:-1,S7P:1,GAP:1})
TKII.add_metabolites({X5P:-1,E4P:-1,F6P:1,GAP:1})
TALA.add_metabolites({S7P:-1,GAP:-1,E4P:1,F6P:1})
GSSGR.add_metabolites({GSSG:-1,NADPH:-1,H:-1,GSH:2,NADP:1})
GSHR.add_metabolites({GSH:-2,GSSG:1,H:2})
NADHQ.add_metabolites({NADH:-1,Q:-1,H:-5,NAD:1,QH2:1,H:4})
SUCCQ.add_metabolites({succinate:-1,Q:-1,fumarate:1,QH2:1})
QUIN.add_metabolites({QH2:-1,Fe3:-2,Q:1,Fe2:2,H:2})
CYTO.add_metabolites({Fe2:-4,H:-8,O2:-1,Fe3:4,H:4,H2O:2})
ATPase.add_metabolites({ATP:-1,H:-4,H2O:-1,ADP:1,H:5,Pi:1})
Phos.add_metabolites({Pi:-1,H2O:-1,H:1,P:2})
ATPPoly.add_metabolites({P:-1,ATP:-1,P:2,ADP:1})
energ.add_metabolites({O2:-0.5,NADH:-1,H:-1,H2O:1,NAD:1})
GLNS.add_metabolites({ADP:1.0,ATP:-1.0,gln:1.0,glu:-1.0,H:1.0,nh4:-1.0,Pi:1.0})
GLUDy.add_metabolites({aketo:1.0,glu:-1.0,H2O:-1.0,H:1.0,NADP:-1.0,NADPH:1.0,nh4:1.0})
GLUN.add_metabolites({gln:-1.0,H2O:-1.0,glu:1.0,nh4:1.0})
GLUSy.add_metabolites({aketo:-1.0,gln:-1.0,glu:2.0,H:-1.0,NADP:1.0,NADH:-1.0})
GLUt2r.add_metabolites({glu:1.0,H:1.0})
GLNabc.add_metabolites({ADP:1.0,ATP:-1.0,gln:1.0,H2O:-1.0,H:1.0,Pi:1.0})
Acetale.add_metabolites({Acetaldehyde:-1})
nh4e.add_metabolites({nh4:-1})
Oxae.add_metabolites({oxaloacetate:-1})
aketoe.add_metabolites({aketo:-1})
Lmalate_e.add_metabolites({Lmalate:-1})
succinate_e.add_metabolites({succinate:-1})
glue.add_metabolites({glu:-1})
glne.add_metabolites({gln:-1})
fumurate_e.add_metabolites({fumarate:-1})
FDPe.add_metabolites({FDP:-1,G3P:-1,DHAP:-1})
PTAr.add_metabolites({AcetylCoA:-1,Pi:-1,CoA:-1,actp:1})
ACK.add_metabolites({actp:-1,ADP:-1,act:1,ATP:1})
ACTe.add_metabolites({act:-1})
MASS.add_metabolites({PG3:-1.496,AcetylCoA:-3.7478,ADP:59.81,aketo:4.1182,ATP:-59.81,CoA:3.7478,E4P:-0.361,F6P:-0.0709,G3P:-0.129,G6P:-0.205,gln:-0.2557,glu:-4.9414,H2O:-59.81,H:59.81,NAD:-3.547,NADH:3.547,NADP:13.0279,NADPH:-13.0279,oxaloacetate:-1.7867,PEP:-0.5191,Pi:59.81,PYR:-2.8328,R5P:-0.8977})

# %%
# model.add_reactions([GLUin,HK,PGI,PFK,TPI,ALD,GAPDH,PGK,PGLM,ENO,PK,PKF,ETH,ETHe,AMPe,APK,PYRe,ATPh,NADHo,AMPin,Pie,He,H2Oe,ACTL,Acetale,nh4e,CIT,Aco1,Aco2,iso,ketod,Succsyn,Succd,Fum,Mald,G6PDH,PGLase,GL6PDH,CO2e,R5PE,R5PI,TKI,TKII,TALA,GSSGR,GSHR,NADHQ,SUCCQ,QUIN,CYTO,ATPase,GLNS,GLUDy,GLUN,GLUSy,GLUt2r,GLNabc,Phos,ATPPoly,energ,Oxae,aketoe,Lmalate_e,succinate_e,glue,glne,fumurate_e,FDPe,PTAr,ACK,ACTe,MASS])

# %%
model.add_reactions([GLUin ,HK ,PGI ,PFK ,TPI ,ALD ,GAPDH,PGK ,PGLM ,ENO ,PK ,PKF ,AMPe ,APK ,PYRe ,ATPh ,NADHo ,AMPin ,He ,H2Oe ,Pie ,ACTL ,CIT ,Aco1 ,Aco2 ,iso ,ketod ,Succsyn ,Succd ,Fum ,Mald ,G6PDH ,PGLase ,GL6PDH ,CO2e ,R5PE ,R5PI ,TKI ,TKII ,TALA ,GSSGR ,GSHR ,NADHQ ,SUCCQ ,QUIN ,CYTO ,ATPase ,Phos ,ATPPoly ,energ,GLNS ,GLUDy ,GLUN ,GLUSy ,GLUt2r,GLNabc ,Acetale ,nh4e ,Oxae ,aketoe ,Lmalate_e ,succinate_e ,glue ,glne ,fumurate_e ,FDPe,LACe ,PTAr ,ACK ,ACTe ,MASS,LDH])
# Out:
# Ignoring reaction 'GLUin' since it already exists.
# Ignoring reaction 'HK' since it already exists.
# Ignoring reaction 'PGI' since it already exists.
# Ignoring reaction 'PFK' since it already exists.
# Ignoring reaction 'TPI' since it already exists.
# Ignoring reaction 'ALD' since it already exists.
# Ignoring reaction 'GAPDH' since it already exists.
# Ignoring reaction 'PGK' since it already exists.
# Ignoring reaction 'PGLM' since it already exists.
# Ignoring reaction 'ENO' since it already exists.
# Ignoring reaction 'PK' since it already exists.
# Ignoring reaction 'PKF' since it already exists.
# Ignoring reaction 'AMPe' since it already exists.
# Ignoring reaction 'APK' since it already exists.
# Ignoring reaction 'PYRe' since it already exists.
# Ignoring reaction 'ATPh' since it already exists.
# Ignoring reaction 'NADHo' since it already exists.
# Ignoring reaction 'AMPin' since it already exists.
# Ignoring reaction 'He' since it already exists.
# ...

# %%
model.objective = 'MASS'

# %%
model.optimize()
# Out:
# <Solution 0.384 at 0x1a3d771e280>

# %%
value=model.optimize()

# %%
cobra.io.save_json_model(model, "PathWays.json")

# %%
builder = Builder(model_json="PathWays.json")

# %%
builder.reaction_data=value.fluxes

# %%
builder
# Out:
# Builder(reaction_data={'GLUin': 1.0, 'HK': 1.0, 'PGI': 0.2999827364625103, 'PFK': 0.4112750081522263, 'TPI': 0…
